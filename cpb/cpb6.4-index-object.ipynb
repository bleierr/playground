# %%
import pandas as pd

# %%
summer = pd.read_csv("DataSets/summer.csv", index_col="Athlete")

# %%
summer.describe()
# Out:
#                Year
# count  31165.000000
# mean    1970.482785
# std       33.158416
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
type(summer.index)
# Out:
# pandas.core.indexes.base.Index

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#        'Medal'],
#       dtype='object')

# %%
type(summer.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
summer.axes
# Out:
# [Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#         'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#         'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#         'NEUMANN, Paul',
#         ...
#         'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#         'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#         'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#         'LIDBERG, Jimmy'],
#        dtype='object', name='Athlete', length=31165),
#  Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#         'Medal'],
#        dtype='object')]

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
summer.reset_index(inplace=True)

# %%
summer.head()
# Out:
#               Athlete  Year    City     Sport Discipline Country Gender  \
# 0       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 1    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
# 2   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
# 3  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 4  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.set_index("Year", inplace=True, drop=False) #drop=False Year column remanins

# %%
summer.index.is_unique
# Out:
# False

# %% [markdown]
# ## Sales data

# %%
summer.head()
# Out:
#                  Athlete  Year    City     Sport Discipline Country Gender  \
# Year
# 1896       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 1896    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
# 1896   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
# 1896  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 1896  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                            Event   Medal
# Year
# 1896              100M Freestyle    Gold
# 1896              100M Freestyle  Silver
# 1896  100M Freestyle For Sailors  Bronze
# 1896  100M Freestyle For Sailors    Gold
# 1896  100M Freestyle For Sailors  Silver

# %%
summer.set_index("Athlete", drop=False, inplace=True)

# %%
summer.head()
# Out:
#                                Athlete  Year    City     Sport Discipline  \
# Athlete
# HAJOS, Alfred            HAJOS, Alfred  1896  Athens  Aquatics   Swimming
# HERSCHMANN, Otto      HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming
# DRIVAS, Dimitrios    DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming
# MALOKINIS, Ioannis  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming
# CHASAPIS, Spiridon  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming
#
#                    Country Gender                       Event   Medal
# Athlete
# HAJOS, Alfred          HUN    Men              100M Freestyle    Gold
# HERSCHMANN, Otto       AUT    Men              100M Freestyle  Silver
# DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors  Silver

# %%
#index objects (index or column) are inmutable, one can only replace the entire list of the index
summer.rename(mapper= {"HAJOS, Alfred" : "HAYOS, Alfred"}, axis="index")
# Out:
#                                              Athlete  Year    City      Sport  \
# Athlete
# HAYOS, Alfred                          HAJOS, Alfred  1896  Athens   Aquatics
# HERSCHMANN, Otto                    HERSCHMANN, Otto  1896  Athens   Aquatics
# DRIVAS, Dimitrios                  DRIVAS, Dimitrios  1896  Athens   Aquatics
# MALOKINIS, Ioannis                MALOKINIS, Ioannis  1896  Athens   Aquatics
# CHASAPIS, Spiridon                CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                              ...   ...     ...        ...
# JANIKOWSKI, Damian                JANIKOWSKI, Damian  2012  London  Wrestling
# REZAEI, Ghasem Gholamreza  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# TOTROV, Rustam                        TOTROV, Rustam  2012  London  Wrestling
# ALEKSANYAN, Artur                  ALEKSANYAN, Artur  2012  London  Wrestling
# LIDBERG, Jimmy                        LIDBERG, Jimmy  2012  London  Wrestling
#
# ...

# %%
summer.rename(index= {"HAJOS, Alfred" : "HAYOS, Alfred"}, inplace=True)

# %%
summer.head()
# Out:
#                                Athlete  Year    City     Sport Discipline  \
# Athlete
# HAYOS, Alfred            HAJOS, Alfred  1896  Athens  Aquatics   Swimming
# HERSCHMANN, Otto      HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming
# DRIVAS, Dimitrios    DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming
# MALOKINIS, Ioannis  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming
# CHASAPIS, Spiridon  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming
#
#                    Country Gender                       Event   Medal
# Athlete
# HAYOS, Alfred          HUN    Men              100M Freestyle    Gold
# HERSCHMANN, Otto       AUT    Men              100M Freestyle  Silver
# DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors  Silver

# %%
summer.rename(mapper= {"Sex" : "Gender"}, axis="columns")
# Out:
#                                              Athlete  Year    City      Sport  \
# Athlete
# HAYOS, Alfred                          HAJOS, Alfred  1896  Athens   Aquatics
# HERSCHMANN, Otto                    HERSCHMANN, Otto  1896  Athens   Aquatics
# DRIVAS, Dimitrios                  DRIVAS, Dimitrios  1896  Athens   Aquatics
# MALOKINIS, Ioannis                MALOKINIS, Ioannis  1896  Athens   Aquatics
# CHASAPIS, Spiridon                CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                              ...   ...     ...        ...
# JANIKOWSKI, Damian                JANIKOWSKI, Damian  2012  London  Wrestling
# REZAEI, Ghasem Gholamreza  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# TOTROV, Rustam                        TOTROV, Rustam  2012  London  Wrestling
# ALEKSANYAN, Artur                  ALEKSANYAN, Artur  2012  London  Wrestling
# LIDBERG, Jimmy                        LIDBERG, Jimmy  2012  London  Wrestling
#
# ...

# %%
summer.rename(columns= {"Gender" : "Sex"}, inplace=True)

# %%
summer
# Out:
#                                              Athlete  Year    City      Sport  \
# Athlete
# HAYOS, Alfred                          HAJOS, Alfred  1896  Athens   Aquatics
# HERSCHMANN, Otto                    HERSCHMANN, Otto  1896  Athens   Aquatics
# DRIVAS, Dimitrios                  DRIVAS, Dimitrios  1896  Athens   Aquatics
# MALOKINIS, Ioannis                MALOKINIS, Ioannis  1896  Athens   Aquatics
# CHASAPIS, Spiridon                CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                              ...   ...     ...        ...
# JANIKOWSKI, Damian                JANIKOWSKI, Damian  2012  London  Wrestling
# REZAEI, Ghasem Gholamreza  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# TOTROV, Rustam                        TOTROV, Rustam  2012  London  Wrestling
# ALEKSANYAN, Artur                  ALEKSANYAN, Artur  2012  London  Wrestling
# LIDBERG, Jimmy                        LIDBERG, Jimmy  2012  London  Wrestling
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df = pd.read_csv("DataSets/players.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...
